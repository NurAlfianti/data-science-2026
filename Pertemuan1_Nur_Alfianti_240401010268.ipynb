# %% [markdown]
# <a href="https://colab.research.google.com/github/NurAlfianti/data-science-2026/blob/main/Pertemuan1_Nur_Alfianti_240401010268.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# SEL 1: Output sederhana
print("Hello, Data Science!")
print("Selamat datang di mata kuliah Pengantar Data Science!")
# Out:
# Hello, Data Science!
# Selamat datang di mata kuliah Pengantar Data Science!

# %%
#SEL 2: Variabel dan tipe data dasar
nama      = "Mahasiswa Informatika" #String
angkatan  = 2024                    # Integer
ipk       = 3.75                    # Float
aktif     = True                    # Boolean

print(f"Nama      : {nama}")
print(f"Angkatan  : {angkatan}")
print(f"IPK       : {nama}")
print(f"Status    : {aktif}")
# Out:
# Nama      : Mahasiswa Informatika
# Angkatan  : 2024
# IPK       : Mahasiswa Informatika
# Status    : True

# %%
#SEL 3 : List dan Looping
tools = ["Python", "Google Colab", "Jupyter Notebook", "Github"]
print("\nTools Data Science yang akan kita pelajari:")
for i, tool in enumerate(tools, 1):
  print(f"  {i}. {tool}")
# Out:
# Tools Data Science yang akan kita pelajari:
#   1. Python
#   2. Google Colab
#   3. Jupyter Notebook
#   4. Github

# %%
#SEL 4 : Fungsi Sederhana
def perkenalan(nama, prodi, angkatan) :
  """Fungsi untuk menampilkan perkenalan mahasiswa."""
  return f"Hai! Saya {nama} dari {prodi}, angakatan {angkatan}."

hasil = perkenalan("Budi Santoso", "Informatika", 2024)
print(hasil)
# Out:
# Hai! Saya Budi Santoso dari Informatika, angakatan 2024.
